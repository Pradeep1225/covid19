# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\Admin\Downloads\archive (3).zip")

# %%
data
# Out:
#           id total_cases new_cases active_cases total_deaths  new_deaths  \
# 0        332      31,506     3,526       26,062        2,503       345.0
# 1        497      31,506     3,526       26,062        2,503       345.0
# 2        662      31,506     3,526       26,062        2,503       345.0
# 3        827      31,506     3,526       26,062        2,503       345.0
# 4        992      31,506     3,526       26,062        2,503       345.0
# ...      ...         ...       ...          ...          ...         ...
# 4245  862839     172,434     3,493      106,962       22,745       575.0
# 4246  863052     172,434     3,493      106,962       22,745       575.0
# 4247  863265     172,434     3,493      106,962       22,745       575.0
# 4248  863478     172,434     3,493      106,962       22,745       575.0
# 4249  863691     172,434     3,493      106,962       22,745       575.0
#
#      total_recovered serious_critical total_cases_per1m record_date
# ...

# %%
data.head()
# Out:
#     id total_cases new_cases active_cases total_deaths  new_deaths  \
# 0  332      31,506     3,526       26,062        2,503       345.0
# 1  497      31,506     3,526       26,062        2,503       345.0
# 2  662      31,506     3,526       26,062        2,503       345.0
# 3  827      31,506     3,526       26,062        2,503       345.0
# 4  992      31,506     3,526       26,062        2,503       345.0
#
#   total_recovered serious_critical total_cases_per1m record_date
# 0           2,941            2,060               NaN     00:05.5
# 1           2,941            2,060               NaN     10:02.6
# 2           2,941            2,060             521.1     20:01.6
# 3           2,941            2,060             521.1     30:02.7
# 4           2,941            2,060             521.1     40:02.2

# %%
data.columns
# Out:
# Index(['id', 'total_cases', 'new_cases', 'active_cases', 'total_deaths',
#        'new_deaths', 'total_recovered', 'serious_critical',
#        'total_cases_per1m', 'record_date'],
#       dtype='object')

# %%
data.tail()
# Out:
#           id total_cases new_cases active_cases total_deaths  new_deaths  \
# 4245  862839     172,434     3,493      106,962       22,745       575.0
# 4246  863052     172,434     3,493      106,962       22,745       575.0
# 4247  863265     172,434     3,493      106,962       22,745       575.0
# 4248  863478     172,434     3,493      106,962       22,745       575.0
# 4249  863691     172,434     3,493      106,962       22,745       575.0
#
#      total_recovered serious_critical total_cases_per1m record_date
# 4245          42,727            2,812             2,852     00:02.5
# 4246          42,727            2,812             2,852     10:02.4
# 4247          42,727            2,812             2,852     20:02.1
# 4248          42,727            2,812             2,852     30:01.8
# 4249          42,727            2,812             2,852     40:02.1

# %%
data.describe()
# Out:
#                   id   new_deaths
# count    4250.000000  1658.000000
# mean   418008.621412   647.603136
# std    251782.447299   131.812161
# min         2.000000   345.000000
# 25%    197627.250000   570.000000
# 50%    411384.500000   627.000000
# 75%    634781.250000   756.000000
# max    863691.000000   919.000000

# %%
data.isnull().sum()
# Out:
# id                      0
# total_cases             0
# new_cases            2592
# active_cases            0
# total_deaths            0
# new_deaths           2592
# total_recovered         0
# serious_critical        0
# total_cases_per1m       3
# record_date             0
# dtype: int64

# %%
#relating the variables with scatterplots

# %%
sns.relplot(x="total_cases",y="total_recovered",data=data)

# %%
sns.relplot(x="total_deaths",y="new_deaths",data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='total_deaths',y='new_deaths',kind='line',data=data)

# %%
sns.relplot(x='total_cases',y='serious_critical',kind='line',data=data)

# %%
sns.relplot(x='total_cases',y='total_recovered',kind='line',data=data)

# %%
sns.catplot(x="total_cases",y="total_recovered",data=data)

# %%
sns.catplot(x="total_deaths",y="new_deaths",data=data)

# %%
sns.catplot(x="total_deaths",y="serious_critical",data=data)
